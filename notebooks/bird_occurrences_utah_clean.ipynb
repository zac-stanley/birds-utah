# %% [markdown]
# ### eBird Occurrence of 11 bird species in the Southwest US centered on Utah
# ***Data from:***
#
# GBIF | Global Biodiversity Information Facility: https://www.gbif.org/
#
# Notebook by Zac Stanley for New Maps Plus - MAP674

# %% [markdown]
# #### Initialize python libraries

# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Read in text file as DataFrame - dataset is huge so I didn't upload to git

# %%
ebird_df = pd.read_csv("C:\\NewMapsPlus\\Map674\\ClassSourceData\\eBird\\Utah\\occurrence.csv")

# %% [markdown]
# #### Inspect the object type returned from read_csv()

# %%
type(ebird_df) # pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # inspect the first fove rows of the dataset

# %%
ebird_df.head()
# Out:
#        gbifID    identifier                   publisher collectionCode  \
# 0  2660970930  OBS699478918  Cornell Lab of Ornithology          EBIRD
# 1  2665361558  OBS711863979  Cornell Lab of Ornithology          EBIRD
# 2  2699437779  OBS787147472  Cornell Lab of Ornithology          EBIRD
# 3  2704471408  OBS797732031  Cornell Lab of Ornithology          EBIRD
# 4  2705880951  OBS801199492  Cornell Lab of Ornithology          EBIRD
#
#                        datasetName      basisOfRecord  \
# 0  EOD - eBird Observation Dataset  HUMAN_OBSERVATION
# 1  EOD - eBird Observation Dataset  HUMAN_OBSERVATION
# 2  EOD - eBird Observation Dataset  HUMAN_OBSERVATION
# 3  EOD - eBird Observation Dataset  HUMAN_OBSERVATION
# 4  EOD - eBird Observation Dataset  HUMAN_OBSERVATION
#
#                          occurrenceID catalogNumber  recordNumber  \
# 0  URN:catalog:CLO:EBIRD:OBS699478918  OBS699478918           NaN
# 1  URN:catalog:CLO:EBIRD:OBS711863979  OBS711863979           NaN
# ...

# %%
# look at the columns - we only need a few of these - lat, lon, vernacular name, year etc.
ebird_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   gbifID                  1048575 non-null  int64
#  1   identifier              1048575 non-null  object
#  2   publisher               1048575 non-null  object
#  3   collectionCode          1048575 non-null  object
#  4   datasetName             1048575 non-null  object
#  5   basisOfRecord           1048575 non-null  object
#  6   occurrenceID            1048575 non-null  object
#  7   catalogNumber           1048575 non-null  object
#  8   recordNumber            0 non-null        float64
#  9   recordedBy              1048575 non-null  object
#  10  individualCount         1021167 non-null  float64
#  11  occurrenceStatus        1048575 non-null  object
#  12  eventDate               1048575 non-null  object
# ...

# %%
ebird_df.drop(['gbifID','identifier','publisher','collectionCode', 'datasetName','basisOfRecord','occurrenceID', 'catalogNumber','recordNumber','recordedBy','eventDate','countryCode','acceptedNameUsageID','kingdom','phylum', 'class', 'order', 'family', 'genus','specificEpithet','taxonRank', 'taxonomicStatus', 'datasetKey', 'publishingCountry','lastInterpreted','hasCoordinate','hasGeospatialIssues','taxonKey', 'acceptedTaxonKey', 'kingdomKey','phylumKey','classKey','orderKey', 'familyKey','genusKey','speciesKey','species','genericName', 'acceptedScientificName', 'protocol', 'lastParsed','lastCrawled','repatriated', 'level0Gid', 'level0Name','level1Gid','level1Name','level2Gid','level2Name'
], axis=1,inplace=True)

# %%
# look at the columns - we only need a few of these - lat, lon, vernacular name, year etc.
ebird_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   individualCount         1021167 non-null  float64
#  1   occurrenceStatus        1048575 non-null  object
#  2   year                    1048575 non-null  int64
#  3   month                   1048575 non-null  int64
#  4   day                     1048575 non-null  int64
#  5   stateProvince           1048575 non-null  object
#  6   county                  1048575 non-null  object
#  7   locality                1048575 non-null  object
#  8   decimalLatitude         1048575 non-null  float64
#  9   decimalLongitude        1048575 non-null  float64
#  10  scientificName          1048575 non-null  object
#  11  vernacularName          1048575 non-null  object
#  12  verbatimScientificName  1048575 non-null  object
# dtypes: float64(3), int64(3), object(7)
# ...

# %%
ebird_df.head()
# Out:
#    individualCount occurrenceStatus  year  month  day stateProvince    county  \
# 0              1.0          PRESENT  2019      1   17          Utah      Utah
# 1              2.0          PRESENT  2019      2   16        Nevada     Clark
# 2              3.0          PRESENT  2019      7   21        Nevada     Clark
# 3              3.0          PRESENT  2019      8   24       Arizona  Coconino
# 4              1.0          PRESENT  2019      6   15      Colorado  Montrose
#
#                                         locality  decimalLatitude  \
# 0  867 E 2260 S, Provo US-UT (40.2036,-111.6432)          40.2036
# 1                                      Las Vegas          36.1750
# 2                     Las Vegas Wash--Pabco Area          36.0877
# 3                             Frances Short Pond          35.2060
# 4             Delta Nucla Road--Tabeguache Basin          38.3663
#
#    decimalLongitude                         scientificName    vernacularName  \
# ...

# %%
# There are way too many records for this dataset to be useful for us. I summarized the data in QGIS and took the average number of counted species
# Plus the five species with occurrences immediately greater and less than the average
# I need to select out that subset now
ebird_subset = ebird_df[(ebird_df['vernacularName'] == 'Wilson\'s Warbler') | (ebird_df['vernacularName'] == 'Bewick\'s Wren')
                        | (ebird_df['vernacularName'] == 'Vesper Sparrow') | (ebird_df['vernacularName'] == 'Loggerhead Shrike')
                        | (ebird_df['vernacularName'] == 'Canyon Wren') | (ebird_df['vernacularName'] == 'Northern Pintail')
                        | (ebird_df['vernacularName'] == 'Clark\'s Nutcracker') | (ebird_df['vernacularName'] == 'Savannah Sparrow')
                        | (ebird_df['vernacularName'] == 'Great Horned Owl') | (ebird_df['vernacularName'] == 'Juniper Titmouse')
                        | (ebird_df['vernacularName'] == 'MacGillivray\'s Warbler')
                       ]

# %%
ebird_subset.info() # 27,975 records is much more reasonable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27975 entries, 24 to 1048556
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   individualCount         27514 non-null  float64
#  1   occurrenceStatus        27975 non-null  object
#  2   year                    27975 non-null  int64
#  3   month                   27975 non-null  int64
#  4   day                     27975 non-null  int64
#  5   stateProvince           27975 non-null  object
#  6   county                  27975 non-null  object
#  7   locality                27975 non-null  object
#  8   decimalLatitude         27975 non-null  float64
#  9   decimalLongitude        27975 non-null  float64
#  10  scientificName          27975 non-null  object
#  11  vernacularName          27975 non-null  object
#  12  verbatimScientificName  27975 non-null  object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 3.0+ MB

# %%
ebird_subset.to_csv('./data/11birdspecies_southwest.csv')
